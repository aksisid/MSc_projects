# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(data=[all_chr1, repeats])
plt.xticks([0, 1], ['All Chr1', 'Repeats'])
plt.ylabel('Complexity Score')
plt.title('Comparison of Complexity: Whole Chr1 vs Repeats')
plt.show()
